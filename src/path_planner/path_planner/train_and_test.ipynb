# %%
###### TODO: 작업 directory를 알맞게 변경 ######
# %cd ~/LG_robot_LSTM_VPG
#############################################

# Jupyter notebook에서 matplotlib figure를 inline으로 표시
# %matplotlib inline

# %% [markdown]
# # Training

# %%
from path_planner.main import main
import sys

args_str = """
    train
    --model-name test.pth
    --valid-freq 1
    --ckp-freq 1
    --use-train-maps
    --use-wandb
"""

sys.argv = [" "] + args_str.split()

# Training
main()

# %% [markdown]
# # Test

# %%
from path_planner.main import main
import sys

args_str = """
    test
    --model-name model.pth
    --test-map-folder-name test
    --test-map-num-per-level 250
    --vis-test-map-num 3
    --min-coverable-area-rate 0.1
"""

sys.argv = [" "] + args_str.split()

# Training
main()

# %% [markdown]
# # Inference

# %%
from path_planner.main import main
import sys

args_str = """
    inference
    --model-name model.pth
    --map-rel-path test/test_map_L1_0000.npy
"""

sys.argv = [" "] + args_str.split()

# Training
main()
